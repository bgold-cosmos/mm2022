# %%
import numpy as np
import matplotlib.pyplot as pp
from scipy.special import jv, jn_zeros
from IPython.display import HTML
from matplotlib import animation

# %%
x = np.linspace(0,20,1000)
pp.plot(x, jv(0,x), 'k-')

# %%
x = np.linspace(0,20,1000)
pp.plot(x, jv(1,x), 'k-')

# %%
x = np.linspace(0,20,1000)
pp.plot(x, jv(2,x), 'k-')

# %%
r,th = np.meshgrid(np.linspace(0,1,10), np.linspace(0,2*np.pi,20))
def pol2cart(r,th):
    return r*(np.cos(th), np.sin(th))

x,y = pol2cart(r,th)

pp.plot(x,y, 'kx')

# %%
jn_zeros(0,5)
# Out:
# array([ 2.40482556,  5.52007811,  8.65372791, 11.79153444, 14.93091771])

# %%
z = jv(0,2.405*r)
fig = pp.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')
ax.plot_surface(x,y,z)

# %%
z = jv(0,jn_zeros(0,5)[1]*r)
fig = pp.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')
ax.plot_surface(x,y,z)

# %%
z = jv(1,jn_zeros(1,5)[0]*r) * np.cos(1*th)
fig = pp.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')
ax.plot_surface(x,y,z)

# %% [markdown]
# try uncommenting the last three lines in the next part and see if that works

# %%
from matplotlib.colors import LightSource
fig = pp.figure(figsize=(16,16))
pp.rcParams["animation.html"]="jshtml"
def drawframe(t):
    ax = fig.add_subplot(projection='3d')
    ax.set(zlim3d=(-1,1))
    z = jv(0,jn_zeros(0,5)[0]*r) * np.sin(t) * 0.4
    return ax.plot_surface(x,y,z,lightsource=LightSource(altdeg=10))

#a = animation.FuncAnimation(fig, drawframe, frames=np.linspace(0,2*np.pi, 20), interval=50)
#pp.close()
#a
