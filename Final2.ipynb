# %%
import numpy as np
import matplotlib.pyplot as pp
import pandas as pd

# %%
d = pd.read_csv('emission data.csv')

# %%
d['Country']
# Out:
# 0                    Afghanistan
# 1                         Africa
# 2                        Albania
# 3                        Algeria
# 4               Americas (other)
#                  ...
# 226    Wallis and Futuna Islands
# 227                        World
# 228                        Yemen
# 229                       Zambia
# 230                     Zimbabwe
# Name: Country, Length: 231, dtype: object

# %%
d2 = d[
    (d['Country'] != 'World')
    & (d['Country'] != 'EU-28') 
    & (d['Country'] != 'Americas (other)')
    & (d['Country'] != 'Asia and Pacific (other)')
    & (d['Country'] != 'Europe (other)')]

# %%
d2
# Out:
#                        Country  1751  1752  1753  1754  1755  1756  1757  \
# 0                  Afghanistan     0     0     0     0     0     0     0
# 1                       Africa     0     0     0     0     0     0     0
# 2                      Albania     0     0     0     0     0     0     0
# 3                      Algeria     0     0     0     0     0     0     0
# 5                      Andorra     0     0     0     0     0     0     0
# ..                         ...   ...   ...   ...   ...   ...   ...   ...
# 225                    Vietnam     0     0     0     0     0     0     0
# 226  Wallis and Futuna Islands     0     0     0     0     0     0     0
# 228                      Yemen     0     0     0     0     0     0     0
# 229                     Zambia     0     0     0     0     0     0     0
# 230                   Zimbabwe     0     0     0     0     0     0     0
#
#      1758  1759  ...          2008          2009          2010          2011  \
# ...

# %%
d3 = d2[np.sum(d2.loc[:,'1751':'2017'], axis=1) > 0]

# %%
d3
# Out:
#                        Country  1751  1752  1753  1754  1755  1756  1757  \
# 0                  Afghanistan     0     0     0     0     0     0     0
# 1                       Africa     0     0     0     0     0     0     0
# 2                      Albania     0     0     0     0     0     0     0
# 3                      Algeria     0     0     0     0     0     0     0
# 5                      Andorra     0     0     0     0     0     0     0
# ..                         ...   ...   ...   ...   ...   ...   ...   ...
# 225                    Vietnam     0     0     0     0     0     0     0
# 226  Wallis and Futuna Islands     0     0     0     0     0     0     0
# 228                      Yemen     0     0     0     0     0     0     0
# 229                     Zambia     0     0     0     0     0     0     0
# 230                   Zimbabwe     0     0     0     0     0     0     0
#
#      1758  1759  ...          2008          2009          2010          2011  \
# ...

# %%
countries = d3['Country'].to_numpy()

# %%
top = np.flip(np.argsort(d3['2015'].to_numpy()))
countries[top[:5]]
# Out:
# array(['United States', 'China', 'Russia', 'Germany', 'United Kingdom'],
#       dtype=object)

# %%
mat = d3.loc[:,'1751':'2017'].to_numpy()

# %%
u,s,vt = np.linalg.svd(mat, full_matrices=False)

# %%
pp.plot(s)
pp.yscale('log')

# %%
np.shape(vt)
# Out:
# (225, 267)

# %%
pp.plot(-vt[0,:], 'k-', -vt[1,:], 'b-', -vt[2,:], 'g-', vt[3,:], 'r-')
